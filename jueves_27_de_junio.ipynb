# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioFuentes7/Cursopython/blob/main/jueves_27_de_junio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import symbols, Integral, sin

x = symbols("x")
intsen = Integral(sin(x), (x,-1,1))
print("El resultado es: ", intsen.evalf())
# Out:
# El resultado es:  0.e-100

# %%
from sympy import symbols, Integrate, exp

# %%
from sympy import symbols, sin
from sympy.plotting import plot
x= symbols("x")

fx =0
for i in range(4):
    fx= fx + sin(i*x)

print(fx)
plot(fx)
# Out:
# sin(x) + sin(2*x) + sin(3*x)

# %%
from sympy import sin, symbols, Abs
from sympy.plotting import plot
def f(x):
    return Abs(Abs(x)-1)
x = symbols("x")

plot(f(x))
plot(f(f(f(x))))
plot(f(x)*f(x), (x, -5, 5), line_color="red")

# %%
from sympy import symbols, Eq
from sympy import plot_implicit
x, y =symbols("x y")
plot_implicit(Eq(x**4-(x**2-y**3),0), (x, -1.5, 1.5),
              (y, -1.5, 1.5));

# %%
from sympy import plot_implicit
from sympy import sqrt, sin
plot_implicit(sin(x**5)+(x-2*y**2)>0, (x,-2,4), (y, -2, 2));

# %%
from sympy import symbols, cos, sin, exp, pi
from sympy import plot_parametric
t = symbols("t")
def x(t):
    return sin(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)
def y(t):
    return cos(t)*(exp(cos(t)) - 2*cos(4*t)-sin(t/12**5))

plot_parametric(x(t), y(t), (t, -6*pi, 6*pi));
plot_parametric(x(t), y(t), (t, -50, 50));

# %%
impot numpy as np
